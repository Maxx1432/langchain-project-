# %%
### Data Ingestion

# %%
###Document Structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a sample document. for creating a document object in langchain to create RAG",
    metadata={"source": "notebook/document.ipynb", "author": "John Doe", "pages":1, "date_created": "2026-06-01"}
)
doc
# Out:
# Document(metadata={'source': 'notebook/document.ipynb', 'author': 'John Doe', 'pages': 1, 'date_created': '2026-06-01'}, page_content='This is a sample document. for creating a document object in langchain to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.text":"""Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.


     Python has a large standard library and a vibrant ecosystem of third-party packages, making it suitable for a wide range of applications, from web development to data science.""",

"../data/text_files/java_intro.text":"""Java is a versatile, object-oriented programming language designed to be platform-independent. It runs on the Java Virtual Machine (JVM), allowing developers to write code once and run it anywhere.

Java is widely used for building enterprise applications, mobile apps (especially Android), and large-scale systems. It has a strong community and extensive libraries that support various functionalities.""",
}

for filepath,content in sample_texts.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader(
    file_path="../data/text_files/python_intro.text",encoding="utf-8"
)
document=loader.load()
print(document)
# Out:
# /var/folders/ks/nsl1h5496r5dk7ycfffv5444b6q6c6/T/ipykernel_72650/1696485328.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.text'}, page_content='Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.\n\n\n     Python has a large standard library and a vibrant ecosystem of third-party packages, making it suitable for a wide range of applications, from web development to data science.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text from the directory
dir_loader=DirectoryLoader(
    path="../data/text_files",
    glob="*.text", ##Pattern to mathc files
    loader_cls=TextLoader, ##Loader class to use
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.text'}, page_content='Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming.\n\n\n     Python has a large standard library and a vibrant ecosystem of third-party packages, making it suitable for a wide range of applications, from web development to data science.'),
#  Document(metadata={'source': '../data/text_files/java_intro.text'}, page_content='Java is a versatile, object-oriented programming language designed to be platform-independent. It runs on the Java Virtual Machine (JVM), allowing developers to write code once and run it anywhere.\n\nJava is widely used for building enterprise applications, mobile apps (especially Android), and large-scale systems. It has a strong community and extensive libraries that support various functionalities.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text from the directory
dir_loader=DirectoryLoader(
    path="../data/pdf_files",
    glob="**/*.pdf", ##Pattern to mathc files
    loader_cls=PyMuPDFLoader, ##Loader class to use
    ##loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Leegality.com', 'creator': '', 'creationdate': '2026-08-18T09:19:10+00:00', 'source': '../data/pdf_files/Audit Trail (1).pdf', 'file_path': '../data/pdf_files/Audit Trail (1).pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'Audit Trail', 'author': 'Leegality.com', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260818091910+00'00'", 'page': 0}, page_content='Audit Trail\nAbout Audit Trail\nThe audit trail records all actions and events related to a document, including document creation, modifications, signatures, and completion\nstatus. It provides a detailed log of activities, ensuring accountability, transparency, and legal validity of the document.\nDocument Details\nS. No.\nDocument name\nDocument ID\nDocument Hash\nCompletion time\n1.\nAxis Used Car Loan A\npplication-ALA000001\n010083\n01M0A1HD72VMAWTCYP92SQ7TMM\n6f56a102964d8a7564f947071e2c1f04cf19c012\n0e522724e38b2f3e32bf6142\n18-08-2026 
# ...

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the md text from the directory
dir_loader=DirectoryLoader(
    path="../data/md_files",
    glob="**/*.md", ##Pattern to mathc files
    loader_cls=TextLoader, ##Loader class to use
    ##loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/md_files/00-overview.md'}, page_content="# Income Assessment Knowledge Base\n\nThis folder is the context pack for **RAG-based developer assistance and onboarding** for the `income-assessment-service`.\n\nThe knowledge base is designed to help developers quickly understand the service's **business domain, architecture, request flows, APIs, integrations, persistence, events, configuration, and troubleshooting paths** without having to inspect the entire repository manually.\n\nThe primary focus is on **production behavior that can be established from the current repository code and configuration**.\n\n---\n\n## 1. Service Overview\n\n### Service\n\n`income-assessment-service`\n\n### Technology\n\n* Language: Kotlin\n* Framework: Spring WebFlux\n* Persistence: MongoDB\n* Messaging: Kafka\n* Configuration: Spring/application configuration and service-specific configuration files\n\n### Business Domain\n\nThe service is responsible for **income veri
# ...
